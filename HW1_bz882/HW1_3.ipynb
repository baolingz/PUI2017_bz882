# %% [markdown]
# # Create a reproducible research chunk of code
#
# That means we want the reader to be able to reproduce every step of the work we do.
#
# If our work includes the use of stochastic processes and random variables that gets tricky: how do we assure the
# random draw gives the same number to the user that it gave to me? That is not random!
#
# That becomes possible because computers are unable to poduce truly random numbers. When we ask a computer to generate a random number, it will in fact generate a "pseudo random" number. The number will be randon in the sanse that it will be some number between, for example, 0 and 1 if we ask for a uniform random distribution or a number near 0 if we aks for a Gaussian distribution with mean 0. But the sequence of pseudo-random numbers that a compujter generates will depend on its **seed**: if you know the seed you know all the numbers that are "randomely" drawn.
#
# You can read more about pseudorandom number generation in this wikipedia article https://en.wikipedia.org/wiki/Pseudorandom_number_generator
# Fill in the empty cells below with code, as directed.

# %%
from __future__ import print_function
__author__ = "Baoling Zhou, CUSP NYU 2016"

# %%
import os
import sys

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np

# %%
##give numpy as seed for this code to be reproducible¶
np.random.seed(56)

# %%
##1. Generate random distributions. use the function.
##to generate 100 2-dimensional random datapoints in a gaussian distribution

ReprRand = np.random.rand(2,100)

# %%
##Print ReprRand
ReprRand
# Out:
# array([[ 0.98419185,  0.33341227,  0.67370162,  0.19639042,  0.35444646,
#          0.81336595,  0.24784955,  0.45861133,  0.87730142,  0.39165846,
#          0.32613342,  0.09009511,  0.83421775,  0.0962116 ,  0.64754508,
#          0.54950399,  0.84974054,  0.26531732,  0.44086832,  0.88088538,
#          0.7363577 ,  0.71264004,  0.03567197,  0.01973123,  0.32779687,
#          0.56301663,  0.74571705,  0.72956789,  0.99019112,  0.96348374,
#          0.55019533,  0.98826167,  0.50925462,  0.34977244,  0.93131972,
#          0.20418216,  0.4011665 ,  0.47219663,  0.13782737,  0.72520272,
#          0.58573674,  0.15652572,  0.78607603,  0.16533818,  0.74433756,
#          0.25925376,  0.7522431 ,  0.12892418,  0.02542097,  0.17658116,
#          0.96746286,  0.28231378,  0.82630069,  0.37215685,  0.46898145,
#          0.18838848,  0.15273557,  0.00164244,  0.4586208 ,  0.03881297,
#          0.73332676,  0.67930388,  0.14609347,  0.53527332,  0.96217297,
# ...

# %%
##if you did this correctly the shape of ReprRand will be (2, 100)
ReprRand.shape
# Out:
# (2, 100)

# %% [markdown]
# # 2. use the same function to generate 50 more random 2x100 numpy arrays and store them in ReprRandAll, all with different mean.
#
# np.random.randn creates a distribution with mean 0 and standard deviation 1 by default.
#
# To obtain a gaussian distribution with a mean different than 1 using np.random.randn you must add your new mean (it is explained in the dunction documentation for which I already gave you the link)
#
# If you want to change the standard deviation (sigma) as well you multiply the distribution by the new sigma.
#
# You can do it in a for loop. The first line of code I included generates an array of zeros that you can fill in with your new numbers.

# %%
np.random.seed(56)
ReprRandAll = np.zeros((50, 2, 100))
for i in range(50):
    ReprRandAll[i] = np.random.rand(2,100) + random.randn()

# %%
##Print ReprRandAll
ReprRandAll
# Out:
# array([[[ 0.28450358,  1.91580491,  2.42482738, ...,  1.33137602,
#           1.14746501,  1.69598306],
#         [ 1.10417349, -0.29678748,  0.9596479 , ..., -2.38823148,
#           0.53432244, -0.27974169]],
#
#        [[-1.79751181, -0.62759528,  0.36140507, ..., -0.42252437,
#          -1.79684022, -1.1316987 ],
#         [-0.06810988,  0.90520418,  1.48893892, ..., -0.67523842,
#           0.09531995,  0.22974657]],
#
#        [[ 0.04758375,  2.46510226,  2.21075314, ..., -0.19264203,
#           2.216596  ,  1.64267449],
#         [ 0.33827458, -1.06357107,  1.04587093, ..., -1.812919  ,
#           0.79677213,  1.81869244]],
#
#        ...,
#        [[ 1.89229072,  0.50492734,  2.31420835, ..., -0.82053839,
#           1.30994775, -0.03163795],
#         [ 0.06882877,  0.58541864,  0.57136355, ..., -0.79351864,
#           0.81310446,  0.78107422]],
#
#        [[-1.0311571 , -1.74122846, -1.14808089, ..., -2.8933872 ,
#          -2.06494274, -2.48328228],
# ...

# %%
#if you did this correctly the shape of ReprRand will be (50, 2, 100)
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %%
import pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

fig = plt.figure(figsize=(8,8))
for i in range(50):
    X = ReprRandAll[i][0] 
    Y = ReprRandAll[i][1]
    plt.scatter(X,Y)

pylab.ylabel('ReprRandAll[i][1]', fontsize=20)
pylab.xlabel('ReprRandAll[i][0]', fontsize=20)
pylab.title('Scatter Plot of array(50,2,100) datapoints in a gaussian distribution', fontsize=20)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 3. now plot them:
#
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to. For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
np.random.seed(56)
ReprRandAll2 = np.zeros((50, 2, 100))
for i in range(50):
    ReprRandAll2[i][0] = np.random.randn(100) + np.random.randn()
    ReprRandAll2[i][1] = np.random.randn(100) + np.random.randn()

# %%
##Populating the interactive namespace from numpy and matplotlib
##Always add a caption to each of your homework figures. 
##And remember to give your labels some names! This is a general rule. 
##Without the caption or axis labels this portion of the HW will not get points. 
##Make sure the font in the labels is large enough to be readable.

fig = plt.figure(figsize=(8,8))
for i in range(50):
    X = ReprRandAll2[i][0] 
    Y = ReprRandAll2[i][1]
    plt.scatter(X,Y)

pylab.ylabel('ReprRandAll2[i][1]', fontsize=20)
pylab.xlabel('ReprRandAll2[i][0]', fontsize=20)
pylab.title('Scatter Plot of array(50,2,100) datapoints in a gaussian distribution', fontsize=20)
