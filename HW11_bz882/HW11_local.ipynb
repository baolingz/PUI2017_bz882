# %%
import os
import zipfile
import urllib.request as urllib

import numpy as np
import pandas as pd
import geopandas as gpd
import pylab as pl

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !for ((y=93; y<=99; y+=1)); do wget \
ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp$y\totals.zip; done

# !for ((y=0; y<=1; y+=1)); do wget \
ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp0$y\totals.zip; done

# !for ((y=2; y<=9; y+=1)); do wget \
ftp://ftp.census.gov/econ200$y\/CBP_CSV/zbp0$y\totals.zip; done

# !for ((y=10; y<=14; y+=1)); do wget \
ftp://ftp.census.gov/econ20$y\/CBP_CSV/zbp$y\totals.zip; done
# Out:
# --2017-12-11 21:42:05--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp93totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2017-12-11 21:42:05 ERROR 404: Not Found.
#
# --2017-12-11 21:42:05--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp94totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 611524 (597K) [application/zip]
# Saving to: “zbp94totals.zip”
#
# 100%[======================================>] 611,524     --.-K/s   in 0.1s
#
# 2017-12-11 21:42:06 (4.37 MB/s) - “zbp94totals.zip” saved [611524/611524]
#
# --2017-12-11 21:42:06--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp95totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625328 (611K) [application/zip]
# Saving to: “zbp95totals.zip”
#
# 100%[======================================>] 625,328     --.-K/s   in 0.03s
#
# 2017-12-11 21:42:06 (23.6 MB/s) - “zbp95totals.zip” saved [625328/625328]
#
# --2017-12-11 21:42:06--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp96totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 632625 (618K) [application/zip]
# Saving to: “zbp96totals.zip”
#
# 100%[======================================>] 632,625     --.-K/s   in 0.04s
#
# 2017-12-11 21:42:06 (16.1 MB/s) - “zbp96totals.zip” saved [632625/632625]
#
# --2017-12-11 21:42:06--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp97totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629368 (615K) [application/zip]
# Saving to: “zbp97totals.zip”
#
# 100%[======================================>] 629,368     --.-K/s   in 0.05s
#
# 2017-12-11 21:42:06 (11.9 MB/s) - “zbp97totals.zip” saved [629368/629368]
#
# --2017-12-11 21:42:06--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp98totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 617784 (603K) [application/zip]
# Saving to: “zbp98totals.zip”
#
# 100%[======================================>] 617,784     --.-K/s   in 0.05s
#
# 2017-12-11 21:42:06 (12.3 MB/s) - “zbp98totals.zip” saved [617784/617784]
#
# --2017-12-11 21:42:06--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp99totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625814 (611K) [application/zip]
# Saving to: “zbp99totals.zip”
#
# 100%[======================================>] 625,814     --.-K/s   in 0.02s
#
# 2017-12-11 21:42:06 (28.3 MB/s) - “zbp99totals.zip” saved [625814/625814]
#
# --2017-12-11 21:42:06--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp00totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628434 (614K) [application/zip]
# Saving to: “zbp00totals.zip”
#
# 100%[======================================>] 628,434     --.-K/s   in 0.04s
#
# 2017-12-11 21:42:06 (13.7 MB/s) - “zbp00totals.zip” saved [628434/628434]
#
# --2017-12-11 21:42:06--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp01totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628815 (614K) [application/zip]
# Saving to: “zbp01totals.zip”
#
# 100%[======================================>] 628,815     --.-K/s   in 0.07s
#
# 2017-12-11 21:42:07 (8.93 MB/s) - “zbp01totals.zip” saved [628815/628815]
#
# --2017-12-11 21:42:07--  https://www2.census.gov/econ2002/CBP_CSV/zbp02totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 620754 (606K) [application/zip]
# Saving to: “zbp02totals.zip”
#
# 100%[======================================>] 620,754     --.-K/s   in 0.04s
#
# 2017-12-11 21:42:07 (15.1 MB/s) - “zbp02totals.zip” saved [620754/620754]
#
# --2017-12-11 21:42:07--  https://www2.census.gov/econ2003/CBP_CSV/zbp03totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 622790 (608K) [application/zip]
# Saving to: “zbp03totals.zip”
#
# 100%[======================================>] 622,790     --.-K/s   in 0.05s
#
# 2017-12-11 21:42:07 (12.9 MB/s) - “zbp03totals.zip” saved [622790/622790]
#
# --2017-12-11 21:42:07--  https://www2.census.gov/econ2004/CBP_CSV/zbp04totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625803 (611K) [application/zip]
# Saving to: “zbp04totals.zip”
#
# 100%[======================================>] 625,803     3.58M/s   in 0.2s
#
# 2017-12-11 21:42:07 (3.58 MB/s) - “zbp04totals.zip” saved [625803/625803]
#
# --2017-12-11 21:42:07--  https://www2.census.gov/econ2005/CBP_CSV/zbp05totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 627583 (613K) [application/zip]
# Saving to: “zbp05totals.zip”
#
# 100%[======================================>] 627,583     --.-K/s   in 0.04s
#
# 2017-12-11 21:42:07 (13.4 MB/s) - “zbp05totals.zip” saved [627583/627583]
#
# --2017-12-11 21:42:07--  https://www2.census.gov/econ2006/CBP_CSV/zbp06totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629107 (614K) [application/zip]
# Saving to: “zbp06totals.zip”
#
# 100%[======================================>] 629,107     --.-K/s   in 0.08s
#
# 2017-12-11 21:42:07 (7.31 MB/s) - “zbp06totals.zip” saved [629107/629107]
#
# --2017-12-11 21:42:07--  https://www2.census.gov/econ2007/CBP_CSV/zbp07totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 667754 (652K) [application/zip]
# Saving to: “zbp07totals.zip”
#
# 100%[======================================>] 667,754     --.-K/s   in 0.02s
#
# 2017-12-11 21:42:07 (30.0 MB/s) - “zbp07totals.zip” saved [667754/667754]
#
# --2017-12-11 21:42:07--  https://www2.census.gov/econ2008/CBP_CSV/zbp08totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 663242 (648K) [application/zip]
# Saving to: “zbp08totals.zip”
#
# 100%[======================================>] 663,242     --.-K/s   in 0.09s
#
# 2017-12-11 21:42:08 (6.90 MB/s) - “zbp08totals.zip” saved [663242/663242]
#
# --2017-12-11 21:42:08--  https://www2.census.gov/econ2009/CBP_CSV/zbp09totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 660109 (645K) [application/zip]
# Saving to: “zbp09totals.zip”
#
# 100%[======================================>] 660,109     --.-K/s   in 0.05s
#
# 2017-12-11 21:42:08 (11.8 MB/s) - “zbp09totals.zip” saved [660109/660109]
#
# --2017-12-11 21:42:08--  https://www2.census.gov/econ2010/CBP_CSV/zbp10totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 797534 (779K) [application/zip]
# Saving to: “zbp10totals.zip”
#
# 100%[======================================>] 797,534     --.-K/s   in 0.03s
#
# 2017-12-11 21:42:08 (24.1 MB/s) - “zbp10totals.zip” saved [797534/797534]
#
# --2017-12-11 21:42:08--  https://www2.census.gov/econ2011/CBP_CSV/zbp11totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 795390 (777K) [application/zip]
# Saving to: “zbp11totals.zip”
#
# 100%[======================================>] 795,390     --.-K/s   in 0.04s
#
# 2017-12-11 21:42:08 (18.0 MB/s) - “zbp11totals.zip” saved [795390/795390]
#
# --2017-12-11 21:42:08--  https://www2.census.gov/econ2012/CBP_CSV/zbp12totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:295::208c, 2600:141b:13:288::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733541 (716K) [application/zip]
# Saving to: “zbp12totals.zip”
#
# 100%[======================================>] 733,541     --.-K/s   in 0.03s
#
# 2017-12-11 21:42:08 (25.8 MB/s) - “zbp12totals.zip” saved [733541/733541]
#
# --2017-12-11 21:42:08--  https://www2.census.gov/econ2013/CBP_CSV/zbp13totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733605 (716K) [application/zip]
# Saving to: “zbp13totals.zip”
#
# 100%[======================================>] 733,605     --.-K/s   in 0.1s
#
# 2017-12-11 21:42:09 (6.28 MB/s) - “zbp13totals.zip” saved [733605/733605]
#
# --2017-12-11 21:42:09--  https://www2.census.gov/econ2014/CBP_CSV/zbp14totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:288::208c, 2600:141b:13:295::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733763 (717K) [application/zip]
# Saving to: “zbp14totals.zip”
#
# 100%[======================================>] 733,763     3.44M/s   in 0.2s
#
# 2017-12-11 21:42:09 (3.44 MB/s) - “zbp14totals.zip” saved [733763/733763]

# %%
l = ['94', '95','96', '97','98','99','00','01','02','03','04','05','06','07','08','09','10','11','12','13','14']

# %%
import pandas as pd
import zipfile 
dfs = []
for i, item in enumerate(l):
    fname = 'zbp' + item + 'totals.zip'
    zf = zipfile.ZipFile(fname)
    df.columns = [c.lower() for c in df.columns]
    df = pd.read_csv(zf.open(fname.replace('.zip','.txt')))
    dfs.append(df)
df1 = pd.concat(dfs)

# %%
df1.shape
# Out:
# (828791, 13)

# %%
df1.to_csv('df1.csv')

# %% [markdown]
# ## Download the NYC zipcodes shapefile

# %%
url = 'https://data.cityofnewyork.us/download/i8iw-xf4u/application/zip'
urllib.urlretrieve(url, 'NYCZIP.zip')
os.system('unzip NYCZIP.zip -d ' + os.getenv('PUIDATA') + '/NYCZIP')
# Out:
# 0

# %%
for fname in os.listdir(os.getenv('PUIDATA') + '/NYCZIP'):
    if fname.endswith('shp'):
        shpfile = fname

zipcode = gpd.GeoDataFrame.from_file(os.getenv('PUIDATA') + '/NYCZIP/' + shpfile)
zipcode.head()
# Out:
#   ZIPCODE BLDGZIP   PO_NAME  POPULATION          AREA STATE  COUNTY ST_FIPS  \
# 0   11436       0   Jamaica     18681.0  2.269930e+07    NY  Queens      36
# 1   11213       0  Brooklyn     62426.0  2.963100e+07    NY   Kings      36
# 2   11212       0  Brooklyn     83866.0  4.197210e+07    NY   Kings      36
# 3   11225       0  Brooklyn     56527.0  2.369863e+07    NY   Kings      36
# 4   11218       0  Brooklyn     72280.0  3.686880e+07    NY   Kings      36
#
#   CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0      081  http://www.usps.com/         0.0        0.0
# 1      047  http://www.usps.com/         0.0        0.0
# 2      047  http://www.usps.com/         0.0        0.0
# 3      047  http://www.usps.com/         0.0        0.0
# 4      047  http://www.usps.com/         0.0        0.0
#
#                                             geometry
# 0  POLYGON ((1038098.251871482 188138.3800067157,...
# 1  POLYGON ((1001613.712964058 186926.4395172149,...
# 2  POLYGON ((1011174.275535807 183696.33770971, 1...
# 3  POLYGON ((995908.3654508889 183617.6128015518,...
# 4  POLYGON ((991997.1134308875 176307.4958601296,...

# %%
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ## Data Cleaning
