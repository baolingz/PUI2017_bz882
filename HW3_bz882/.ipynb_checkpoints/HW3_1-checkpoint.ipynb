# %%
from __future__ import print_function
__author__ = "Baoling Zhou, CUSP NYU 2017"
import numpy as np
import matplotlib.pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#GENERATE 100 samples of different sizes N (N>10 & N<2000) from each of 5 different distributions 
#(500 samples in total), all with the same population mean
#Include a Normal, a Poisson, a Binomial, a Chi-Squared distribution, and 1 more of your choice.
np.random.seed(56)
N = np.random.uniform(low=10, high=2000, size=(100,))
N = N.astype(int)
N.tolist()
N
# Out:
# array([1968,  673, 1350,  400,  715, 1628,  503,  922, 1755,  789,  659,
#         189, 1670,  201, 1298, 1103, 1700,  537,  887, 1762, 1475, 1428,
#          80,   49,  662, 1130, 1493, 1461, 1980, 1927, 1104, 1976, 1023,
#         706, 1863,  416,  808,  949,  284, 1453, 1175,  321, 1574,  339,
#        1491,  525, 1506,  266,   60,  361, 1935,  571, 1654,  750,  943,
#         384,  313,   13,  922,   87, 1469, 1361,  300, 1075, 1924, 1478,
#        1873,  661, 1698, 1747,  309,   44,  875,  812,  674,   80,  451,
#         735, 1060, 1510, 1387,  229, 1977, 1877, 1006, 1368,  979,  454,
#         803, 1023, 1933,  421, 1036, 1148, 1775, 1383,  889, 1450,  131,
#          75])

# %%
#normal_mean = []
#for i in range(100):
#    normal_mean.append(np.random.normal(loc=10,size = round(N[i])).mean())

# %%
#plt.hist(normal_mean);

# %%
from __future__ import print_function
__author__= 'fbb'

import pylab as pl
# this package sets up pretty plots
import seaborn
from scipy.optimize import curve_fit, minimize
    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mymean = 100

# %%
# the chi sq distribution takes the number of degrees of freedom, which luckily is the same as the mean!
df = mymean

# %%
md = {}
# md is an empty disctionary
md['chisq'] = np.random.chisquare(df, size=100)
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 100.29, standard deviation: 14.34

# %%
# I am gonna overwrite the disctionary entry created into a nested dictionary 
# the outside dictionary hosts the distributions as dictionary, 
# and each distribution dictionary contains the 100 distribution (arrays of diferent sizes)

md['chisq'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in N:
    md['chisq'][n] = np.random.normal(loc=mymean,scale=5, size = n)
    
# save the means for plotting later    

md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(N), max(N)], [df, df], 'k')

# %%
allmeans = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %%
md['lnorm'] = np.random.normal(loc=mymean,scale=5, size=100)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['lnorm'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Normal mean: %.2f, standard deviation: %.2f"%(md['lnorm'].mean(), md['lnorm'].std()))
# Out:
# Normal mean: 99.86, standard deviation: 4.86

# %%
md['lnorm'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in N:
    md['lnorm'][n] = np.random.normal(loc = mymean,scale = 5, size = n)
    
# save the means for plotting later    

md['lnorm']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['lnorm']:
    if not type(nn) == str:
        md['lnorm']['means'][nn] = md['lnorm'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['lnorm']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Normal Distribution', fontsize=18)
        axchisq_mu_n.plot([min(N), max(N)], [mymean, mymean], 'k')

# %%
allmeans = list(md['lnorm']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %%
# Note: I am adding imports here, to show the workflow: 
# at this point I realize what packages I need and I import them. 
# but this is a PEP8 violation. 
# It is a good habit to put the includes at the top 
# so the code fails right away if the packages are missing. 
# Otherwise a user may have a piece of code running for a long time, 
# and then fail when the package cannot be imported... 
# (unless they are only imported under conditions, e.g. in an if statement)
import numpy as np

md['pois'] = np.random.poisson(mymean, 100)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Poisson mean: %.2f, standard deviation: %.2f"%(md['pois'].mean(), md['pois'].std()))
# Out:
# Poisson mean: 101.00, standard deviation: 10.25

# %%
# I am gonna overwrite the disctionary entry created into a nested dictionary 
# the outside dictionary hosts the distributions as dictionary, 
# and each distribution dictionary contains the 100 distribution (arrays of diferent sizes)

md['pois'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in N:
    md['pois'][n] = np.random.poisson(mymean, size = n)
    
# save the means for plotting later    

md['pois']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Poisson', fontsize=18)
        axchisq_mu_n.plot([min(N), max(N)], [mymean, mymean], 'k')

# %%
allmeans = list(md['pois']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %%
import numpy as np
md['binomial'] = np.random.binomial(n = 200, p = 0.5, size= 100)
# md now is a dictionary with one object: an array by the key 'binomial'
pl.hist(md['binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(md['binomial'].mean(), md['binomial'].std()))
# Out:
# Binomial mean: 99.80, standard deviation: 6.39

# %%
# I am gonna overwrite the disctionary entry created into a nested dictionary 
# the outside dictionary hosts the distributions as dictionary, 
# and each distribution dictionary contains the 100 distribution (arrays of diferent sizes)

md['binomial'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in N:
    md['binomial'][n] = np.random.binomial(n = 200, p = 0.5, size= n)
    
# save the means for plotting later    

md['binomial']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('binomial', fontsize=18)
        axchisq_mu_n.plot([min(N), max(N)], [100, 100], 'k')

# %%
allmeans = list(md['binomial']['means'].values())
pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %%
md['nbinomial'] = np.random.negative_binomial(100,p = 0.5, size = 100)
# md now is a dictionary with one object: an array by the key 'binomial'
pl.hist(md['nbinomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
np.random.negative_binomial?

# %%
print ("negative_binomial mean: %.2f, standard deviation: %.2f"%(md['nbinomial'].mean(), md['nbinomial'].std()))
# Out:
# negative_binomial mean: 101.33, standard deviation: 12.21

# %%
# I am gonna overwrite the disctionary entry created into a nested dictionary 
# the outside dictionary hosts the distributions as dictionary, 
# and each distribution dictionary contains the 100 distribution (arrays of diferent sizes)

md['nbinomial'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in N:
    md['nbinomial'][n] = np.random.negative_binomial(n = 100, p = 0.5, size= n)
    
# save the means for plotting later    

md['nbinomial']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['nbinomial']:
    if not type(nn) == str:
        md['nbinomial']['means'][nn] = md['nbinomial'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['nbinomial']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('nbinomial', fontsize=18)
        axchisq_mu_n.plot([min(N), max(N)], [100, 100], 'k')

# %%
md['nbinomial'] = np.random.negative_binomial(100,p = 0.5, size = 100)
# md now is a dictionary with one object: an array by the key 'binomial'
pl.hist(md['nbinomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
md.keys()
# Out:
# dict_keys(['chisq', 'lnorm', 'pois', 'binomial', 'nbinomial'])
